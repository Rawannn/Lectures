# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline 
# this statement allows the visuals to render within your Jupyter Notebook

# %% [markdown]
# # Create a chart

# %%
# Create a chart using lists, 
plt.plot([1,2,0,4,5]) # x >> index starts from 0, y >>[1,2,0,4,5]

# %%
x = [10,20, 30, 50, 80]
plt.plot(x, [1,2,0,4,5])

# %%
# to print only the chart
plt.plot([1,2,0,4,5])
plt.show()

# %%
# try to use ; sign >> its same the idea of printing
plt.plot([1,2,0,4,5]);

# %%
'Hello'
# Out:
# 'Hello'

# %%
print('Hello')
# Out:
# Hello

# %%
# Multiple Lines
plt.plot([1,2,0,4,5])
plt.plot([10,9,8,6,3])

# %%
# Create a chart using Numpy Arrays
plt.plot(np.array([9,5,3,7]))

# %%
# Create a chart using Series
plt.plot(pd.Series([9,5,3,7]))

# %%
# Create a chart using dataframe
plt.plot(pd.DataFrame([9,5,3,7]))

# %% [markdown]
# # Types of Charts

# %%
# Line Chart
x = np.arange(0, 100) # generate a sequence of values between 0 and 99 (end value not include)
y = np.random.randint(5, size=100) # random 100 integers (from 0 to 4)
plt.plot(x, y)

# %%
# Bar Chart
x = np.arange(10)
y = np.arange(10)
plt.bar(x, y)
# Out:
# <BarContainer object of 10 artists>

# %%
# Scatter Plot
x = np.random.randn(500)
y = np.random.randn(500)
plt.scatter(x, y)

# %%
plt.scatter(x,y,alpha = 0.5) # alpha between 0 (transparent) and 1 (opaque)

# %%
plt.scatter(x, y, marker = '+', s = 100) # s >> size

# %%
plt.plot([1, 2, 3, 4], [3,5,8,9], marker = 'o', markersize = 15, markerfacecolor = 'green', markeredgewidth= 3, 
        markeredgecolor= 'red')

# %%
# Histogram
x = np.random.randn(500) 
plt.hist(x,10); # bins = 10 means 10 bars

# %%
# Pie Chart
plt.pie(np.arange(1,5),labels=['Jan','Feb','Mar', 'Apr']);

# %%
plt.pie(np.arange(1,5), labels=['Jan','Feb','Mar', 'Apr'], explode = [.1,.2,.3,0]);

# %% [markdown]
# # Formatting Charts

# %%
# Add title
plt.pie(np.arange(1,5),labels=['Jan','Feb','Mar', 'Apr']);
plt.title('Months', fontsize = 30, loc='center', color='b');

# %%
# Add x and y axises
x = np.arange(10)
y = np.arange(10)
plt.bar(x, y)
plt.xlabel('Days')
plt.ylabel('Sales')
# Out:
# Text(0, 0.5, 'Sales')

# %%
# Add Gridlines
plt.bar(x, y)
plt.xlabel('Days')
plt.ylabel('Sales');
plt.grid()

# %%
# Multiple Lines
plt.plot([1,2,0,4,5])
plt.plot([10,9,8,6,3])
# Add Legends
plt.legend(['2008','2009'], shadow = True, loc = 0) # location (0 = best)
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.legend.html

# %%
# Multiple Lines
plt.plot([1,2,0,4,5])
plt.plot([10,9,8,6,3])
plt.legend(['2008','2009'], shadow = True, loc = 'center')

# %%
plt.plot([1,2,0,4,5])
plt.plot([10,9,8,6,3])
plt.legend(['2008','2009'], shadow = True, loc = (0.2, 0.4))

# %%
# Colors
# https://matplotlib.org/stable/gallery/color/named_colors.html
plt.plot([1,2,0,4,5], 'g')
plt.plot([10,9,8,6,3], c ='lime')
plt.plot([12,13, 10, 20,13], color ='blue')

# %%
# RGB Colors
# https://matplotlib.org/stable/tutorials/colors/colors.html
plt.plot([1,2,0,4,5], '#4B0082')
plt.plot([10,9,8,6,3], c ='#029386')
plt.plot([12,13, 10, 20,13], color ='#A52A2A');

# %%
# Line Style and width
# https://matplotlib.org/2.1.1/api/_as_gen/matplotlib.pyplot.plot.html
plt.plot([1,2,0,4,5], linestyle = '--', linewidth = 2, c ='#4B0082')
plt.plot([10,9,8,6,3], ls = ':', lw = 3, c ='#029386') # lw = linewidth, ls = linestyle
plt.plot([12,13, 10, 20,13],  linestyle = '-', linewidth = 1, color ='#A52A2A')

# %%
# Figure Size
plt.figure(figsize = [10,5]) #[width, height]
plt.plot([1,2,0,4,5], linestyle = '--', linewidth = 2, c ='#4B0082')
plt.plot([10,9,8,6,3], linestyle = ':', linewidth = 3, c ='#029386')
plt.plot([12,13, 10, 20,13],  linestyle = '-', linewidth = 1, color ='#A52A2A')

# %% [markdown]
# # Subplots

# %%
plt.pie(np.arange(1,5),labels=['Jan','Feb','Mar', 'Apr']);

# %%
plt.plot([1,2,0,4,5])
plt.plot([10,9,8,6,3])
plt.legend(['2008','2009'], shadow = True, loc = 0)

# %%
plt.figure(figsize=[20,5])
plt.suptitle('Subplots',fontsize = 16)

#first
plt.subplot(1,2,1) #(number of rows, number of columns, number of plot)
plt.pie(np.arange(1,5),labels=['Jan','Feb','Mar', 'Apr']);
plt.title('Months')

#second
plt.subplot(1,2,2)
plt.plot([1,2,0,4,5])
plt.plot([10,9,8,6,3])
plt.legend(['2008','2009'], shadow = True, loc = 0)
plt.title('Years');

# %%
# Removing the Axis
plt.plot([1,2,0,4,5])
plt.plot([10,9,8,6,3])
plt.legend(['2008','2009'], shadow = True, loc = 0)
plt.axis('off');

# %%
# save images
plt.plot([1,2,0,4,5])
plt.plot([10,9,8,6,3])
plt.legend(['2008','2009'], shadow = True, loc = 0)
plt.savefig('mychart.png')

# %%
plt.plot([1,2,0,4,5])
plt.plot([10,9,8,6,3])
plt.legend(['2008','2009'], shadow = False, loc = 0)
plt.savefig('/Users/Noura/Desktop/mychart.png')

# %%
plt.plot([1,2,0,4,5])
plt.plot([10,9,8,6,3])
plt.legend(['2008','2009'], shadow = True, loc = 0)
# Dots Per Inch (DPI) >> resolution of the image
plt.savefig('/Users/Noura/Desktop/mychart2.png', dpi=300)
